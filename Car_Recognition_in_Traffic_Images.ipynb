# %% [markdown]
# <a href="https://colab.research.google.com/github/MYoussef885/Car-Detection-in-Traffic-Images/blob/main/Car_Recognition_in_Traffic_Images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# !pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-11-30 Python-3.10.12 torch-2.1.0+cu118 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %%
img = 'https://www.its.ucla.edu/wp-content/uploads/sites/6/2018/01/los-angeles-1396606_960_720.jpg'

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 614x960 1 person, 27 cars, 5 trucks
# Speed: 446.4ms pre-process, 522.3ms inference, 40.8ms NMS per image at shape (1, 3, 416, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
results.render()
# Out:
# [array([[[ 42,  60,  98],
#          [ 41,  59,  97],
#          [ 41,  59,  99],
#          ...,
#          [ 27,  37,  38],
#          [ 31,  41,  40],
#          [ 35,  45,  44]],
#
#         [[ 39,  57,  95],
#          [ 41,  59,  97],
#          [ 43,  61, 101],
#          ...,
#          [ 19,  29,  30],
#          [ 33,  43,  42],
#          [ 44,  54,  53]],
#
#         [[ 40,  58,  96],
#          [ 41,  59,  97],
#          [ 43,  63, 100],
#          ...,
#          [ 25,  35,  36],
#          [ 32,  42,  41],
#          [ 34,  44,  43]],
#
#         ...,
#
#         [[ 16,  27,  45],
#          [ 16,  27,  45],
#          [ 14,  27,  44],
#          ...,
#          [ 17,  21,  30],
#          [ 15,  17,  29],
#          [ 16,  16,  28]],
#
#         [[ 16,  27,  45],
#          [ 16,  27,  45],
#          [ 14,  27,  44],
#          ...,
#          [ 18,  22,  31],
#          [ 16,  18,  30],
#          [ 16,  18,  31]],
#
#         [[ 16,  27,  45],
# ...

# %%
np.array(results.render()).shape
# Out:
# (1, 614, 960, 3)
